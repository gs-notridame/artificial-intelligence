# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key='uhI1qWKhbgKeqGnUWfe2')
project = rf.workspace().project('skin-disease-finder')
model = project.version(1).model

# Imagem para teste do modelo:
print(model.predict("/content/brain-26.png", confidence=40, overlap=30).json())

# Imagem para teste do modelo:
model.predict("/content/brain-26.png", confidence=40, overlap=30).save("/content/brain-26.png")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# {'predictions': [], 'image': {'width': '469', 'height': '467'}}

# %%
# Monstrando o treinamento funcionando pela imagem

import cv2

from google.colab.patches import cv2_imshow

imagem = cv2.imread('/content/images/brain-26.png')

cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=469x467>
